# %%
import double_jpeg_compression as double_compress
import noise_variance as noise_forgery
import os
import sys

# %%
os.listdir("images")
# Out:
# ['comp30.jpg', 'clint.jpg', 'face_recog.jpg']

# %%
file = "images/clint.jpg"

# %%
state = double_compress.detect(file)
print(state)
# Out:
# False

# %%
state2 = noise_forgery.detect(file)
state2
# Out:
# /home/reganmatics/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# True
